# %% [markdown]
# <a href="https://colab.research.google.com/github/dzulfqr/testing/blob/master/final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification

# %% [markdown]
# Dalam project kali ini, saya mencoba mengklasifikasikan gambar member boygroup BTS. Pengklasifikasi gambar menggunakan model `keras.Sequential`, dan data dimuat menggunakan `preprocessing.image_dataset_from_directory`.
#
# Berikut alur kerja machine learning dasar yang digunakan:
#
# 1. Menelaah dan memahami data
# 2. Bangun input pipeline
# 3. Bangun modelnya
# 4. Latih modelnya (Training)
# 5. Uji modelnya
# 6. Tingkatkan model dan ulangi prosesnya

# %% [markdown]
# ## Import TensorFlow dan libraries lainnya

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Memuat dataset yang sudah dibuat sebelumnya

# %% [markdown]
# Project ini menggunakan dataset sekitar 2.361 foto member BTS. Dataset berisi 7 sub-direktori, satu per kelas (setiap membernya):
#
# ```
# cropped/
#   jhope/
#   jimin/
#   jin/
#   jungkook/
#   rm/
#   suga/
#   v/
# ```

# %%
import pathlib

# %%
# !unzip -q cropped.zip
# !ls

# %%
# !ls cropped
# Out:
# jhope  jimin  jin  jungkook  rm  suga  v

# %%
data_dir = pathlib.Path('/content/cropped')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 2361

# %% [markdown]
# Berikut beberapa gambar dari salah satu member, J-Hope:

# %%
jhope = list(data_dir.glob('jhope/*'))
PIL.Image.open(str(jhope[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=142x161 at 0x7F0CCAE3ACD0>

# %%
PIL.Image.open(str(jhope[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=179x187 at 0x7F0CCA7F6910>

# %% [markdown]
# Jin

# %%
jin = list(data_dir.glob('jin/*'))
PIL.Image.open(str(jin[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=173x189 at 0x7F0CCA7BC0D0>

# %%
PIL.Image.open(str(jin[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=280x280 at 0x7F0CCA7BC2D0>

# %%
root_path = '/content/cropped'
train_pred_test_folders = os.listdir(root_path)

seg_train_folders = '/content/cropped' #one more seg_train folder within

quantity_tr = {} 

for folder in os.listdir(seg_train_folders):
    quantity_tr[folder] = len(os.listdir(seg_train_folders+'/'+folder))
 
quantity_train = pd.DataFrame(list(quantity_tr.items()), index=range(0,len(quantity_tr)), columns=['class','count'])

figure, ax = plt.subplots(1,1,figsize=(20,5))
sns.barplot(x='class',y='count',data=quantity_train,ax=ax)

print("Jumlah gambar dalam dataset : ", sum(quantity_tr.values()))

plt.show()
# Out:
# Jumlah gambar dalam dataset :  2361

# %% [markdown]
# # Memuat data dengan keras.preprocessing
#
# Memuat gambar-gambar ini dari disk menggunakan [image_dataset_from_directory](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory). Hal ini akan membawa kita dari direktori gambar pada disk ke `tf.data.Dataset` hanya dalam beberapa baris kode. Berikut adalah dokumentasi detail mengenai cara memuat data yang dimiliki oleh kita sendiri, seperti yang saya lakukan -> [memuat gambar](https://www.tensorflow.org/tutorials/load_data/images).

# %% [markdown]
# ## Membuat dataset

# %% [markdown]
# Tentukan beberapa parameter untuk loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Ini adalah good practice untuk menggunakan validation split saat mengembangkan suatu model. Mari kita gunakan 80% dari gambar untuk training, dan 20% untuk validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size, smart_resize=True)
# Out:
# Found 2361 files belonging to 7 classes.
# Using 1889 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size, smart_resize=True)
# Out:
# Found 2361 files belonging to 7 classes.
# Using 472 files for validation.

# %% [markdown]
# Anda dapat menemukan nama kelas dalam atribut `class_names` pada kumpulan data ini. Ini sesuai dengan nama direktori dalam urutan abjad.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['jhope', 'jimin', 'jin', 'jungkook', 'rm', 'suga', 'v']

# %% [markdown]
# ## Visualisasikan datanya
#
# Berikut adalah 9 gambar pertama dari training dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Latih model menggunakan set data ini dengan menyimpannya pada function `model.fit` . Selain itu, kita juga dapat secara manual melakukan iterasi kumpulan data dan mengambil kumpulan gambar (batches):

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# `image_batch` adalah tensor dari shape `(32, 180, 180, 3)`. Ini adalah kumpulan 32 gambar berbentuk `180x180x3` (dimensi terakhir mengacu pada saluran warna RGB). `label_batch` adalah tensor dari shape `(32,)`, ini adalah label yang bersesuaian dengan 32 gambar.
#
# Kita dapat memanggil `.numpy()` pada tensor `image_batch` dan `labels_batch` untuk mengonversinya menjadi `numpy.ndarray`.

# %% [markdown]
# ## Konfigurasikan dataset untuk performance
#
# Mari pastikan untuk menggunakan buffered prefetching sehingga kita dapat menghasilkan data dari disk tanpa I/O menjadi blocking. Ini adalah dua metode penting yang harus digunakan saat memuat data.
#
# `Dataset.cache()` menyimpan gambar dalam memori setelah dimuat dari disk selama epoch pertama. Ini akan memastikan kumpulan data tidak menjadi hambatan saat melatih model kita. Jika kumpulan data yang dimiliki terlalu besar untuk dimasukkan ke dalam memori, kita juga dapat menggunakan metode ini untuk membuat cache di disk yang berkinerja baik.
#
# `Dataset.prefetch()` overlaps dengan prapemrosesan data dan eksekusi model saat pelatihan/training.
#
# Berikut informasi lebih lanjut tentang kedua metode tersebut, serta cara menyimpan data ke dalam cache di [data performance guide](https://www.tensorflow.org/guide/data_performance#prefetching).

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standarisasi data

# %% [markdown]
# Nilai channel RGB berada dalam kisaran `[0, 255]`. Ini tidak ideal untuk neural network; secara umum kita harus berusaha membuat nilai input kita menjadi kecil. Di sini, kita akan menstandardisasi nilai agar berada dalam rentang `[0, 1]` dengan menggunakan layer Rescaling.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# Ada dua cara untuk menggunakan layer ini. Kita dapat menerapkannya ke dataset dengan memanggil map:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# Atau, kita dapat menyertakan lapisan di dalam definisi model kita, yang dapat menyederhanakan penerapan. Mari kita gunakan pendekatan kedua di sini.

# %% [markdown]
# Catatan: kita sebelumnya mengubah ukuran gambar menggunakan argumen `image_size` dari `image_dataset_from_directory`. Jika kita juga ingin menyertakan resizing logic dalam model, kita pun dapat menggunakan layer [Resizing](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Resizing).

# %% [markdown]
# # Buat modelnya
#
# Model ini terdiri dari tiga blok konvolusi dengan max pool layer di masing-masing blok. Ada layer yang sepenuhnya terhubung dengan 128 unit di atasnya yang diaktifkan oleh fungsi aktivasi `relu`. Model ini belum disetel untuk akurasi tinggi, sebagai pendekatan standar.

# %%
num_classes = 7

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Kompilasi modelnya
#
# Untuk project ini, pilih fungsi pengoptimal `optimizers.Adam` dan `losses.SparseCategoricalCrossentropy`. Untuk melihat akurasi pelatihan dan validasi untuk setiap periode pelatihan, pass argumen `metrics`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Ringkasan model
#
# Lihat semua layer jaringan menggunakan metode `summary` model:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 3,989,543
# Trainable params: 3,989,543
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 33s 34ms/step - loss: 2.0095 - accuracy: 0.1572 - val_loss: 1.9278 - val_accuracy: 0.1610
# Epoch 2/10
# 60/60 [==============================] - 1s 20ms/step - loss: 1.8618 - accuracy: 0.2372 - val_loss: 1.8744 - val_accuracy: 0.2945
# Epoch 3/10
# 60/60 [==============================] - 1s 20ms/step - loss: 1.6193 - accuracy: 0.3976 - val_loss: 1.6795 - val_accuracy: 0.3390
# Epoch 4/10
# 60/60 [==============================] - 1s 20ms/step - loss: 1.1423 - accuracy: 0.6040 - val_loss: 1.6047 - val_accuracy: 0.4788
# Epoch 5/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.6610 - accuracy: 0.7761 - val_loss: 1.8485 - val_accuracy: 0.5000
# Epoch 6/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.3171 - accuracy: 0.9010 - val_loss: 2.2152 - val_accuracy: 0.5360
# Epoch 7/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1377 - accuracy: 0.9587 - val_loss: 2.4963 - val_accuracy: 0.5593
# Epoch 8/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0477 - accuracy: 0.9894 - val_loss: 2.5545 - val_accuracy: 0.5720
# Epoch 9/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0138 - accuracy: 0.9979 - val_loss: 2.9667 - val_accuracy: 0.5805
# Epoch 10/10
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 3.1353 - val_accuracy: 0.5742

# %% [markdown]
# ## Visualisasikan hasil pelatihan

# %% [markdown]
# Buat plot loss dan akurasi pada set pelatihan dan validasi.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Seperti yang dapat kita lihat dari plot, akurasi pelatihan dan akurasi validasi berbeda jauh dan model hanya mencapai akurasi sekitar 60% pada set validasi.
#
# Mari kita lihat apa yang salah dan coba tingkatkan kinerja model secara keseluruhan.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# Dalam plot di atas, akurasi pelatihan meningkat secara linier dari waktu ke waktu, sedangkan akurasi validasi terhenti sekitar 60% dalam proses pelatihan. Juga, perbedaan akurasi antara akurasi pelatihan dan validasi terlihat — tanda dari [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# Ketika hanya ada sejumlah kecil examples untuk training, model terkadang "belajar" dari noises atau detail yang tidak diinginkan dari examples pelatihan — hal itu berdampak negatif pada kinerja model pada examples baru. Fenomena ini dikenal sebagai overfitting. Ini berarti bahwa model akan mengalami kesulitan untuk melakukan generalisasi pada dataset baru.
#
# Ada beberapa cara untuk mengatasi overfitting dalam proses pelatihan. Dalam project ini, kita akan menggunakan *data augmentation* dan menambahkan *Dropout* ke model kita.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting umumnya terjadi ketika hanya ada sejumlah kecil examples untuk pelatihan. [Data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) mengambil pendekatan untuk menghasilkan data pelatihan tambahan dari contoh yang ada dengan menambahkannya menggunakan transformasi acak yang menghasilkan gambar lainnya. Ini membantu mengekspos model ke lebih banyak aspek data dan menggeneralisasi lebih baik.
#
# Kita akan menerapkan augmentasi data menggunakan layers dari `tf.keras.layers.experimental.preprocessing`. Ini dapat dimasukkan ke dalam model kita seperti layers lain, dan berjalan di GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(factor=0.15),
    layers.experimental.preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.experimental.preprocessing.RandomZoom(0.05)
  ]
)

# %% [markdown]
# Mari kita visualisasikan seperti apa beberapa contoh augmented dengan menerapkan augmentasi data ke gambar yang sama beberapa kali:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ## Dropout
#
# Teknik lain untuk mengurangi overfitting adalah dengan memperkenalkan [Dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization) pada network, salah satu bentuk *regularization*.
#
# Saat kita menerapkan Dropout ke suatu layer, itu secara acak menjatuhkan (drops out) (dengan mengatur aktivasi ke nol) sejumlah unit keluaran dari layer selama proses pelatihan. Dropout mengambil angka pecahan sebagai nilai inputnya, dalam bentuk seperti 0.1, 0.2, 0.4, dll. Ini berarti drop out 10%, 20% atau 40% dari unit output secara acak dari layer yang diterapkan.
#
# Mari buat neural network baru menggunakan `layers.Dropout`, lalu latih menggunakan gambar yang diperbesar.

# %%
# model = Sequential([
#   data_augmentation,
#   layers.experimental.preprocessing.Rescaling(1./255),
#   layers.Conv2D(16, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(32, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(64, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Dropout(0.4),
#   layers.Flatten(),
#   layers.Dense(128, activation='relu'),
#   layers.Dense(num_classes)
# ])

# %% [markdown]
# ## Compile dan train model

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=(img_width, img_height) + (3,), num_classes=num_classes)
keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 180, 180, 3) 0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 180, 180, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# rescaling_3 (Rescaling)         (None, 180, 180, 3)  0           sequential_1[1][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 90, 90, 32)   896         rescaling_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 90, 90, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 90, 90, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 90, 90, 64)   18496       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 90, 90, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 90, 90, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 90, 90, 64)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 90, 90, 128)  8896        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 90, 90, 128)  512         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 90, 90, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 90, 90, 128)  17664       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 90, 90, 128)  512         separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 45, 45, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 45, 45, 128)  8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 45, 45, 128)  0           max_pooling2d_7[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 45, 45, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 45, 45, 256)  34176       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 45, 45, 256)  1024        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 45, 45, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 45, 45, 256)  68096       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 45, 45, 256)  1024        separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 23, 23, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 23, 23, 256)  33024       add_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 23, 23, 256)  0           max_pooling2d_8[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 23, 23, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 23, 23, 512)  133888      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 23, 23, 512)  2048        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 23, 23, 512)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 23, 23, 512)  267264      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 23, 23, 512)  2048        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 12, 12, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 12, 512)  131584      add_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 512)  0           max_pooling2d_9[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 12, 12, 728)  378072      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 728)  2912        separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 728)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 12, 12, 728)  537264      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 728)  2912        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 6, 6, 728)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 6, 6, 728)    373464      add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 728)    0           max_pooling2d_10[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 6, 6, 1024)   753048      add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 1024)   4096        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 1024)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1024)         0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 7)            7175        dropout_1[0][0]
# ==================================================================================================
# Total params: 2,788,799
# Trainable params: 2,780,063
# Non-trainable params: 8,736
# __________________________________________________________________________________________________

# %%
epochs = 75

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
    keras.callbacks.EarlyStopping(monitor='loss', patience=5)
]
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

history = model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/75
# 60/60 [==============================] - 17s 253ms/step - loss: 2.1418 - accuracy: 0.1810 - val_loss: 1.9474 - val_accuracy: 0.1314
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/75
# 60/60 [==============================] - 15s 251ms/step - loss: 2.0128 - accuracy: 0.1853 - val_loss: 1.9663 - val_accuracy: 0.1441
# Epoch 3/75
# 60/60 [==============================] - 15s 251ms/step - loss: 1.9804 - accuracy: 0.2065 - val_loss: 1.9851 - val_accuracy: 0.1398
# Epoch 4/75
# 60/60 [==============================] - 15s 253ms/step - loss: 1.9347 - accuracy: 0.2218 - val_loss: 1.9800 - val_accuracy: 0.1314
# Epoch 5/75
# 60/60 [==============================] - 15s 251ms/step - loss: 1.9349 - accuracy: 0.2155 - val_loss: 1.9693 - val_accuracy: 0.1314
# Epoch 6/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.9147 - accuracy: 0.2298 - val_loss: 1.9984 - val_accuracy: 0.1314
# Epoch 7/75
# 60/60 [==============================] - 15s 250ms/step - loss: 1.8662 - accuracy: 0.2499 - val_loss: 2.0320 - val_accuracy: 0.1314
# Epoch 8/75
# 60/60 [==============================] - 15s 253ms/step - loss: 1.8484 - accuracy: 0.2435 - val_loss: 2.0733 - val_accuracy: 0.1292
# Epoch 9/75
# 60/60 [==============================] - 15s 256ms/step - loss: 1.8542 - accuracy: 0.2615 - val_loss: 1.9496 - val_accuracy: 0.2140
# Epoch 10/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.8096 - accuracy: 0.2747 - val_loss: 1.8894 - val_accuracy: 0.2648
# Epoch 11/75
# 60/60 [==============================] - 15s 255ms/step - loss: 1.7831 - accuracy: 0.2959 - val_loss: 3.0426 - val_accuracy: 0.1419
# Epoch 12/75
# 60/60 [==============================] - 15s 255ms/step - loss: 1.7730 - accuracy: 0.2864 - val_loss: 2.2742 - val_accuracy: 0.1843
# Epoch 13/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.7755 - accuracy: 0.2996 - val_loss: 2.3439 - val_accuracy: 0.2097
# Epoch 14/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.7331 - accuracy: 0.3250 - val_loss: 2.7764 - val_accuracy: 0.2119
# Epoch 15/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.6999 - accuracy: 0.3404 - val_loss: 2.2712 - val_accuracy: 0.2013
# Epoch 16/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.6742 - accuracy: 0.3473 - val_loss: 2.3388 - val_accuracy: 0.1568
# Epoch 17/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.6759 - accuracy: 0.3526 - val_loss: 1.9210 - val_accuracy: 0.3432
# Epoch 18/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.6136 - accuracy: 0.3817 - val_loss: 2.7227 - val_accuracy: 0.2648
# Epoch 19/75
# 60/60 [==============================] - 15s 252ms/step - loss: 1.5798 - accuracy: 0.3933 - val_loss: 1.9515 - val_accuracy: 0.3496
# Epoch 20/75
# 60/60 [==============================] - 15s 255ms/step - loss: 1.5412 - accuracy: 0.4240 - val_loss: 2.0636 - val_accuracy: 0.3326
# Epoch 21/75
# 60/60 [==============================] - 15s 255ms/step - loss: 1.4933 - accuracy: 0.4341 - val_loss: 2.5693 - val_accuracy: 0.2903
# Epoch 22/75
# 60/60 [==============================] - 15s 255ms/step - loss: 1.4914 - accuracy: 0.4272 - val_loss: 2.1346 - val_accuracy: 0.3898
# Epoch 23/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.4041 - accuracy: 0.4807 - val_loss: 2.3309 - val_accuracy: 0.2966
# Epoch 24/75
# 60/60 [==============================] - 15s 253ms/step - loss: 1.3957 - accuracy: 0.4865 - val_loss: 1.9386 - val_accuracy: 0.4534
# Epoch 25/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.3129 - accuracy: 0.5352 - val_loss: 2.4706 - val_accuracy: 0.3305
# Epoch 26/75
# 60/60 [==============================] - 15s 251ms/step - loss: 1.2832 - accuracy: 0.5199 - val_loss: 3.0947 - val_accuracy: 0.2119
# Epoch 27/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.2505 - accuracy: 0.5283 - val_loss: 3.0186 - val_accuracy: 0.2903
# Epoch 28/75
# 60/60 [==============================] - 15s 253ms/step - loss: 1.1562 - accuracy: 0.5807 - val_loss: 2.3144 - val_accuracy: 0.2945
# Epoch 29/75
# 60/60 [==============================] - 15s 253ms/step - loss: 1.1458 - accuracy: 0.5765 - val_loss: 2.2254 - val_accuracy: 0.4343
# Epoch 30/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.0939 - accuracy: 0.6051 - val_loss: 2.3895 - val_accuracy: 0.3093
# Epoch 31/75
# 60/60 [==============================] - 15s 254ms/step - loss: 1.0373 - accuracy: 0.6247 - val_loss: 2.0830 - val_accuracy: 0.4809
# Epoch 32/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.9618 - accuracy: 0.6490 - val_loss: 1.7757 - val_accuracy: 0.4216
# Epoch 33/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.9530 - accuracy: 0.6681 - val_loss: 3.3874 - val_accuracy: 0.3051
# Epoch 34/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.9313 - accuracy: 0.6670 - val_loss: 1.6539 - val_accuracy: 0.4767
# Epoch 35/75
# 60/60 [==============================] - 15s 255ms/step - loss: 0.9120 - accuracy: 0.6649 - val_loss: 1.8600 - val_accuracy: 0.4555
# Epoch 36/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.8234 - accuracy: 0.7104 - val_loss: 2.2189 - val_accuracy: 0.3729
# Epoch 37/75
# 60/60 [==============================] - 15s 255ms/step - loss: 0.8117 - accuracy: 0.7210 - val_loss: 2.3859 - val_accuracy: 0.2733
# Epoch 38/75
# 60/60 [==============================] - 15s 256ms/step - loss: 0.7659 - accuracy: 0.7268 - val_loss: 2.7100 - val_accuracy: 0.3877
# Epoch 39/75
# 60/60 [==============================] - 15s 255ms/step - loss: 0.7547 - accuracy: 0.7406 - val_loss: 3.1692 - val_accuracy: 0.3220
# Epoch 40/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.7458 - accuracy: 0.7374 - val_loss: 1.9640 - val_accuracy: 0.4936
# Epoch 41/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.6785 - accuracy: 0.7702 - val_loss: 1.6268 - val_accuracy: 0.5572
# Epoch 42/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.6707 - accuracy: 0.7623 - val_loss: 2.0530 - val_accuracy: 0.4725
# Epoch 43/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.6126 - accuracy: 0.7819 - val_loss: 1.9957 - val_accuracy: 0.5212
# Epoch 44/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.5866 - accuracy: 0.8004 - val_loss: 1.7485 - val_accuracy: 0.6059
# Epoch 45/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.5894 - accuracy: 0.7983 - val_loss: 1.9883 - val_accuracy: 0.4894
# Epoch 46/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.5380 - accuracy: 0.8084 - val_loss: 2.1805 - val_accuracy: 0.5127
# Epoch 47/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.4806 - accuracy: 0.8412 - val_loss: 1.4532 - val_accuracy: 0.6081
# Epoch 48/75
# 60/60 [==============================] - 15s 251ms/step - loss: 0.4929 - accuracy: 0.8280 - val_loss: 1.7957 - val_accuracy: 0.5614
# Epoch 49/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.4910 - accuracy: 0.8216 - val_loss: 1.5282 - val_accuracy: 0.6801
# Epoch 50/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.4611 - accuracy: 0.8422 - val_loss: 2.2577 - val_accuracy: 0.5339
# Epoch 51/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.4570 - accuracy: 0.8449 - val_loss: 3.6911 - val_accuracy: 0.3898
# Epoch 52/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.4664 - accuracy: 0.8348 - val_loss: 2.3922 - val_accuracy: 0.5042
# Epoch 53/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.3939 - accuracy: 0.8661 - val_loss: 3.0209 - val_accuracy: 0.4492
# Epoch 54/75
# 60/60 [==============================] - 15s 255ms/step - loss: 0.4260 - accuracy: 0.8544 - val_loss: 1.3391 - val_accuracy: 0.6441
# Epoch 55/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.3686 - accuracy: 0.8729 - val_loss: 1.9855 - val_accuracy: 0.5826
# Epoch 56/75
# 60/60 [==============================] - 15s 257ms/step - loss: 0.3814 - accuracy: 0.8629 - val_loss: 1.3995 - val_accuracy: 0.6525
# Epoch 57/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.3973 - accuracy: 0.8555 - val_loss: 1.7622 - val_accuracy: 0.5678
# Epoch 58/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.3641 - accuracy: 0.8708 - val_loss: 1.5671 - val_accuracy: 0.6271
# Epoch 59/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.3015 - accuracy: 0.9005 - val_loss: 2.7423 - val_accuracy: 0.5572
# Epoch 60/75
# 60/60 [==============================] - 15s 256ms/step - loss: 0.3535 - accuracy: 0.8851 - val_loss: 2.1175 - val_accuracy: 0.4746
# Epoch 61/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.3080 - accuracy: 0.8888 - val_loss: 2.3631 - val_accuracy: 0.5720
# Epoch 62/75
# 60/60 [==============================] - 15s 259ms/step - loss: 0.2717 - accuracy: 0.9084 - val_loss: 2.2535 - val_accuracy: 0.5466
# Epoch 63/75
# 60/60 [==============================] - 15s 256ms/step - loss: 0.3033 - accuracy: 0.8936 - val_loss: 1.8492 - val_accuracy: 0.5784
# Epoch 64/75
# 60/60 [==============================] - 15s 256ms/step - loss: 0.3020 - accuracy: 0.9047 - val_loss: 1.7225 - val_accuracy: 0.6483
# Epoch 65/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.2591 - accuracy: 0.9084 - val_loss: 1.9599 - val_accuracy: 0.5847
# Epoch 66/75
# 60/60 [==============================] - 15s 260ms/step - loss: 0.2798 - accuracy: 0.9005 - val_loss: 1.8195 - val_accuracy: 0.5275
# Epoch 67/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.2581 - accuracy: 0.9127 - val_loss: 3.1252 - val_accuracy: 0.5106
# Epoch 68/75
# 60/60 [==============================] - 15s 252ms/step - loss: 0.3291 - accuracy: 0.8841 - val_loss: 2.8444 - val_accuracy: 0.4343
# Epoch 69/75
# 60/60 [==============================] - 15s 256ms/step - loss: 0.2536 - accuracy: 0.9111 - val_loss: 1.7022 - val_accuracy: 0.7076
# Epoch 70/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.2222 - accuracy: 0.9222 - val_loss: 3.1144 - val_accuracy: 0.5318
# Epoch 71/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.2882 - accuracy: 0.8994 - val_loss: 1.8911 - val_accuracy: 0.6419
# Epoch 72/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.2548 - accuracy: 0.9100 - val_loss: 1.9990 - val_accuracy: 0.6059
# Epoch 73/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.2274 - accuracy: 0.9201 - val_loss: 1.9181 - val_accuracy: 0.6314
# Epoch 74/75
# 60/60 [==============================] - 15s 254ms/step - loss: 0.2367 - accuracy: 0.9185 - val_loss: 1.2243 - val_accuracy: 0.7436
# Epoch 75/75
# 60/60 [==============================] - 15s 253ms/step - loss: 0.1948 - accuracy: 0.9359 - val_loss: 1.6176 - val_accuracy: 0.6250

# %% [markdown]
# ## Visualisasikan hasil training
#
# Setelah menerapkan augmentasi data dan Dropout, overfitting lebih sedikit daripada sebelumnya, dan akurasi pelatihan dan validasi lebih selaras.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
val_loss.index(min(val_loss))
# Out:
# 73

# %% [markdown]
# ## Memprediksi data baru

# %% [markdown]
# Terakhir, mari gunakan model kita untuk mengklasifikasikan gambar yang tidak disertakan dalam set pelatihan atau validasi.

# %% [markdown]
# Catatan: Layer augmentasi data dan Dropout tidak aktif pada waktu inference.

# %%
# model = tf.keras.models.load_model('save_at_75.h5')

# %%
img = keras.preprocessing.image.load_img(
    '/content/suga.jpg', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "Gambar ini kemungkinan besar adalah {} dengan {:.2f} % confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Gambar ini kemungkinan besar adalah suga dengan 31.17 % confidence.

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x7F0C695F6A10>

# %%
# model = tf.keras.models.load_model('save_at_75.h5')

# %%
results = model.predict(val_ds)
results.shape
# Out:
# (472, 7)

# %%
from sklearn.metrics import confusion_matrix
true_categories = tf.concat([y for x, y in val_ds], axis=0)
predicted_categories = tf.argmax(results, axis=1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import itertools
#from mlxtend.plotting import plot_confusion_matrix
def clf_report(true_value, model_pred):
    
    classes = class_names
    
    plt.figure(figsize=(7,7))
    cm = confusion_matrix(model_pred, true_value)
    plt.imshow(cm,interpolation='nearest',cmap=plt.cm.viridis)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm.max()*0.8
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,cm[i,j],
                horizontalalignment="center",
                color="black" if cm[i,j] > thresh else "white")
        pass
    
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    pass
    
    print(classification_report(true_value, model_pred, target_names = list(classes)))

# %%
clf_report(true_categories, predicted_categories)
# Out:
#               precision    recall  f1-score   support
#
#        jhope       0.86      0.46      0.60        68
#        jimin       0.71      0.60      0.65        68
#          jin       0.94      0.24      0.38        62
#     jungkook       0.67      0.57      0.62        68
#           rm       0.96      0.71      0.82        70
#         suga       0.48      0.89      0.62        76
#            v       0.47      0.85      0.60        60
#
#     accuracy                           0.62       472
#    macro avg       0.73      0.62      0.61       472
# weighted avg       0.72      0.62      0.62       472
